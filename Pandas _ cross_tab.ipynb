# %% [markdown]
# ## Crosstab :
# - It provides a convenient way to analyze and compare the categorical features.

# %%
import pandas as pd

# %%
import numpy as np

# %%
dfedu = pd.read_csv(r"C:\Users\hp\Desktop\DATASETS\Data mining dataset\Crosstab\crosstab_dataset.csv")

# %%
dfedu
# Out:
#         Name  Gender Country         Degree  Age
# 0     Shanti  Female   India  Post Graduate   23
# 1      Naren    Male   India       Graduate   20
# 2      Kumar    Male   India       Graduate   27
# 3    Narayan    Male   India  Post Graduate   25
# 4      Shiva    Male   India       Graduate   28
# 5      Meena  Female   India  Post Graduate   25
# 6      Akash    Male   India       Graduate   24
# 7    Sandhya  Female   India       Graduate   26
# 8    Kumaran    Male   India       Graduate   27
# 9      Naren    Male   India  Post Graduate   25
# 10    Swarna  Female   India  Post Graduate   28
# 11  Srikruti  Female   India  Post Graduate   25
# 12   Rus_f01  Female  Russia       Graduate   30
# 13   Rus_m01    Male  Russia       Graduate   32
# 14   Rus_f02  Female  Russia  Post Graduate   28
# 15   Rus_f03  Female  Russia       Graduate   34
# 16   Rus_m02    Male  Russia       Graduate   30
# 17   Rus_f04  Female  Russia  Post Graduate   36
# ...

# %%
dfedu["Country"].unique()
# Out:
# array(['India', 'Russia', 'Usa'], dtype=object)

# %%
dfedu["Country"].value_counts()
# Out:
# India     12
# Usa       10
# Russia     7
# Name: Country, dtype: int64

# %%
dfedu["Country"].value_counts().plot(kind = "pie")
# Out:
# <AxesSubplot:ylabel='Country'>

# %%
dfedu["Country"].value_counts().plot(kind = "bar")
# Out:
# <AxesSubplot:>

# %%
dfedu
# Out:
#         Name  Gender Country         Degree  Age
# 0     Shanti  Female   India  Post Graduate   23
# 1      Naren    Male   India       Graduate   20
# 2      Kumar    Male   India       Graduate   27
# 3    Narayan    Male   India  Post Graduate   25
# 4      Shiva    Male   India       Graduate   28
# 5      Meena  Female   India  Post Graduate   25
# 6      Akash    Male   India       Graduate   24
# 7    Sandhya  Female   India       Graduate   26
# 8    Kumaran    Male   India       Graduate   27
# 9      Naren    Male   India  Post Graduate   25
# 10    Swarna  Female   India  Post Graduate   28
# 11  Srikruti  Female   India  Post Graduate   25
# 12   Rus_f01  Female  Russia       Graduate   30
# 13   Rus_m01    Male  Russia       Graduate   32
# 14   Rus_f02  Female  Russia  Post Graduate   28
# 15   Rus_f03  Female  Russia       Graduate   34
# 16   Rus_m02    Male  Russia       Graduate   30
# 17   Rus_f04  Female  Russia  Post Graduate   36
# ...

# %%
pd.crosstab(index = dfedu["Country"], columns=dfedu["Gender"])
# Out:
# Gender   Female  Male
# Country
# India         5     7
# Russia        4     3
# Usa           6     4

# %%
pd.crosstab(index = dfedu["Country"], columns=dfedu["Gender"], margins=True)
# Out:
# Gender   Female  Male  All
# Country
# India         5     7   12
# Russia        4     3    7
# Usa           6     4   10
# All          15    14   29

# %%
pd.crosstab(index = dfedu["Country"], columns = dfedu["Degree"])
# Out:
# Degree   Graduate  Post Graduate
# Country
# India           6              6
# Russia          5              2
# Usa             5              5

# %%
pd.crosstab(index = dfedu["Country"], columns = dfedu["Degree"], margins=True)
# Out:
# Degree   Graduate  Post Graduate  All
# Country
# India           6              6   12
# Russia          5              2    7
# Usa             5              5   10
# All            16             13   29

# %%
pd.crosstab(index = dfedu["Gender"], columns= dfedu["Degree"])
# Out:
# Degree  Graduate  Post Graduate
# Gender
# Female         7              8
# Male           9              5

# %%
pd.crosstab(index = dfedu["Gender"], columns= dfedu["Degree"], margins=True)
# Out:
# Degree  Graduate  Post Graduate  All
# Gender
# Female         7              8   15
# Male           9              5   14
# All           16             13   29

# %%
pd.crosstab(index = [dfedu["Country"], dfedu["Gender"]], columns= dfedu["Degree"] )
# Out:
# Degree          Graduate  Post Graduate
# Country Gender
# India   Female         1              4
#         Male           5              2
# Russia  Female         2              2
#         Male           3              0
# Usa     Female         4              2
#         Male           1              3

# %%
pd.crosstab(index = [dfedu["Country"], dfedu["Gender"]], columns= dfedu["Degree"], margins = True)
# Out:
# Degree          Graduate  Post Graduate  All
# Country Gender
# India   Female         1              4    5
#         Male           5              2    7
# Russia  Female         2              2    4
#         Male           3              0    3
# Usa     Female         4              2    6
#         Male           1              3    4
# All                   16             13   29

# %%
dfct = pd.crosstab(index = dfedu["Country"], columns= [dfedu["Gender"], dfedu["Degree"]], margins = True)

# %%
dfct
# Out:
# Gender    Female                   Male               All
# Degree  Graduate Post Graduate Graduate Post Graduate
# Country
# India          1             4        5             2  12
# Russia         2             2        3             0   7
# Usa            4             2        1             3  10
# All            7             8        9             5  29

# %%
dfct["Female"]
# Out:
# Degree   Graduate  Post Graduate
# Country
# India           1              4
# Russia          2              2
# Usa             4              2
# All             7              8

# %%
pd.crosstab(index = dfedu["Country"], columns=dfedu["Gender"])
# Out:
# Gender   Female  Male
# Country
# India         5     7
# Russia        4     3
# Usa           6     4

# %%
dfedu
# Out:
#         Name  Gender Country         Degree  Age
# 0     Shanti  Female   India  Post Graduate   23
# 1      Naren    Male   India       Graduate   20
# 2      Kumar    Male   India       Graduate   27
# 3    Narayan    Male   India  Post Graduate   25
# 4      Shiva    Male   India       Graduate   28
# 5      Meena  Female   India  Post Graduate   25
# 6      Akash    Male   India       Graduate   24
# 7    Sandhya  Female   India       Graduate   26
# 8    Kumaran    Male   India       Graduate   27
# 9      Naren    Male   India  Post Graduate   25
# 10    Swarna  Female   India  Post Graduate   28
# 11  Srikruti  Female   India  Post Graduate   25
# 12   Rus_f01  Female  Russia       Graduate   30
# 13   Rus_m01    Male  Russia       Graduate   32
# 14   Rus_f02  Female  Russia  Post Graduate   28
# 15   Rus_f03  Female  Russia       Graduate   34
# 16   Rus_m02    Male  Russia       Graduate   30
# 17   Rus_f04  Female  Russia  Post Graduate   36
# ...

# %%
pd.crosstab(index = dfedu["Country"], columns=dfedu["Gender"], values=dfedu["Age"], aggfunc="mean")
# Out:
# Gender      Female       Male
# Country
# India    25.400000  25.142857
# Russia   32.000000  29.333333
# Usa      29.833333  31.500000

# %%
pd.crosstab(index = [dfedu["Country"], dfedu["Gender"] ], columns = dfedu["Degree"])
# Out:
# Degree          Graduate  Post Graduate
# Country Gender
# India   Female         1              4
#         Male           5              2
# Russia  Female         2              2
#         Male           3              0
# Usa     Female         4              2
#         Male           1              3

# %%
pd.crosstab(index = [dfedu["Country"], dfedu["Gender"] ], columns = dfedu["Degree"], 
            values = dfedu["Age"], aggfunc="mean")
# Out:
# Degree           Graduate  Post Graduate
# Country Gender
# India   Female  26.000000          25.25
#         Male    25.200000          25.00
# Russia  Female  32.000000          32.00
#         Male    29.333333            NaN
# Usa     Female  29.250000          31.00
#         Male    27.000000          33.00

# %%
dfedu
# Out:
#         Name  Gender Country         Degree  Age
# 0     Shanti  Female   India  Post Graduate   23
# 1      Naren    Male   India       Graduate   20
# 2      Kumar    Male   India       Graduate   27
# 3    Narayan    Male   India  Post Graduate   25
# 4      Shiva    Male   India       Graduate   28
# 5      Meena  Female   India  Post Graduate   25
# 6      Akash    Male   India       Graduate   24
# 7    Sandhya  Female   India       Graduate   26
# 8    Kumaran    Male   India       Graduate   27
# 9      Naren    Male   India  Post Graduate   25
# 10    Swarna  Female   India  Post Graduate   28
# 11  Srikruti  Female   India  Post Graduate   25
# 12   Rus_f01  Female  Russia       Graduate   30
# 13   Rus_m01    Male  Russia       Graduate   32
# 14   Rus_f02  Female  Russia  Post Graduate   28
# 15   Rus_f03  Female  Russia       Graduate   34
# 16   Rus_m02    Male  Russia       Graduate   30
# 17   Rus_f04  Female  Russia  Post Graduate   36
# ...

# %%
pd.crosstab(dfedu["Country"], dfedu["Gender"], values=dfedu["Age"], aggfunc="mean")
# Out:
# Gender      Female       Male
# Country
# India    25.400000  25.142857
# Russia   32.000000  29.333333
# Usa      29.833333  31.500000

# %%
pd.crosstab(dfedu["Country"], dfedu["Gender"])
# Out:
# Gender   Female  Male
# Country
# India         5     7
# Russia        4     3
# Usa           6     4

# %%
pd.crosstab(dfedu["Country"], dfedu["Gender"], values=dfedu["Age"], aggfunc="mean", normalize=True)
# Out:
# Gender     Female      Male
# Country
# India    0.146643  0.145159
# Russia   0.184747  0.169352
# Usa      0.172238  0.181861

# %%
pd.crosstab(dfedu["Country"], dfedu["Gender"])
# Out:
# Gender   Female  Male
# Country
# India         5     7
# Russia        4     3
# Usa           6     4

# %%
pd.crosstab(dfedu["Country"], dfedu["Gender"], normalize=True, margins = True)
# Out:
# Gender     Female      Male       All
# Country
# India    0.172414  0.241379  0.413793
# Russia   0.137931  0.103448  0.241379
# Usa      0.206897  0.137931  0.344828
# All      0.517241  0.482759  1.000000
